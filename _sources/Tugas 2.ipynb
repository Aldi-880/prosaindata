# %% [markdown]
# # **Pipelines (Tugas 2)**

# %% [markdown]
# pipeline adalah tahapan pemrosesan data. Ia dimulai dari sumber data.
#
# Dari sana, data akan diproses. Di akhir pipeline, ia bermuara di suatu tujuan.

# %% [markdown]
# ## Sepal width

# %%
import orchest
import pandas as pd
from sklearn import datasets

# %%
import os
import urllib.parse as up
import psycopg2

# create connection
up.uses_netloc.append("postgres")
url = up.urlparse("postgres://fgqfjkfd:FwhQSzCARyaSHrAkQ_iEUAts_NxMFLr_@floppy.db.elephantsql.com/fgqfjkfd")
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, 
                        host=url.hostname, port=url.port)

# %%
import sqlalchemy as db 
from sqlalchemy import create_engine

# get table from ElephentSQL
engine = create_engine("postgresql+psycopg2://fgqfjkfd:FwhQSzCARyaSHrAkQ_iEUAts_NxMFLr_@floppy.db.elephantsql.com/fgqfjkfd")
connection = engine.connect()
metadata = db.MetaData()
iris_data = db.Table('iris_data', metadata, autoload=True, autoload_with=engine)
elephantsql_db = db.Table('iris_data', metadata, autoload=True, autoload_with=engine)

# %%
query = db.select([elephantsql_db.columns.id, elephantsql_db.columns.sepal_width])
results = connection.execute(query).fetchall()
df = pd.DataFrame(results)
df.columns = results[0].keys()
df.head(5)
